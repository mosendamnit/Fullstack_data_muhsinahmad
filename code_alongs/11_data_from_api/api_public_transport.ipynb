# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000001&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
len(result["Trip"])
# Out:
# 5

# %%
result["Trip"]
# Out:
# [{'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '15:24:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 8,
#    'prognosisType': 'PROGNOSED',
#    'time': '19:52:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '15. jan t o m 9. jun 2025; utom 19. jan, 2., 8., 9. feb, 1., 2., 15., 16. mar, 26., 27. apr, 1. t o m 4. maj 2025, 17. maj, 6. t o m 8. jun 2025',
#     'sDaysB': '007FBFFEF9FFFFCFFF3FFFFFFFFFCE1FFEFFFFE200'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '15:24:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 8,
#       'prognosisType': 'PROGNOSED',
#       'time': '19:52:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'X2000',
#         'key': 'VX',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'X2000'},
#        {'value': 'Mat 1 klass',
#         'key': 'A1',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Mat 1 klass'},
#        {'value': 'Bistrovagn',
#         'key': 'AD',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Bistrovagn'},
#        {'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'WiFi',
#         'key': 'AW',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'WiFi'},
#        {'value': '2 klass lugn',
#         'key': 'BL',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': '2 klass lugn'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Maträtt',
#         'key': 'SM',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Maträtt'},
#        {'value': '1 klass med extra komfort',
#         'key': 'SU',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': '1 klass med extra komfort'},
#        {'value': 'Kaffebuffé 1 klass',
#         'key': 'SZ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Kaffebuffé 1 klass'}]},
#      'JourneyDetailRef': {'ref': '1|1003|0|1|15012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'SJ',
#         'nameS': '74',
#         'nameN': '74',
#         'nameL': 'SJ',
#         'id': '74'},
#        'name': 'Snabbtåg 539',
#        'internalName': 'Snabbtåg 539',
#        'displayNumber': '539',
#        'num': '539',
#        'line': '539',
#        'lineId': '1074053900002',
#        'catOut': 'JST',
#        'catIn': 'JST',
#        'catCode': '1',
#        'cls': '2',
#        'catOutS': 'JST',
#        'catOutL': 'Snabbtåg',
#        'operatorCode': '74',
#        'operator': 'SJ',
#        'admin': '074___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 8,
#        'matchId': '539;539;43737'}],
#      'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#         'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#         'extId': '740000001',
#         'routeIdx': 0,
#         'lon': 18.058151,
#         'lat': 59.330136,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '15:24:00',
#         'depDate': '2025-01-15',
#         'depDir': 'Malmö Centralstation',
#         'minimumChangeDuration': 'PT20M'},
#        {'name': 'Norrköping Centralstation',
#         'id': 'A=1@O=Norrköping Centralstation@X=16183343@Y=58596625@U=1@L=740000007@',
#         'extId': '740000007',
#         'routeIdx': 1,
#         'lon': 16.183343,
#         'lat': 58.596625,
#         'depTime': '16:40:00',
#         'depDate': '2025-01-15',
#         'arrTime': '16:39:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Linköping Centralstation',
#         'id': 'A=1@O=Linköping Centralstation@X=15624960@Y=58416634@U=1@L=740000009@',
#         'extId': '740000009',
#         'routeIdx': 2,
#         'lon': 15.62496,
#         'lat': 58.416634,
#         'depTime': '17:07:00',
#         'depDate': '2025-01-15',
#         'arrTime': '17:05:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Nässjö Centralstation',
#         'id': 'A=1@O=Nässjö Centralstation@X=14693983@Y=57652443@U=1@L=740000140@',
#         'extId': '740000140',
#         'routeIdx': 3,
#         'lon': 14.693983,
#         'lat': 57.652443,
#         'depTime': '17:55:00',
#         'depDate': '2025-01-15',
#         'arrTime': '17:54:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Alvesta station',
#         'id': 'A=1@O=Alvesta station@X=14556322@Y=56898778@U=1@L=740000004@',
#         'extId': '740000004',
#         'routeIdx': 4,
#         'lon': 14.556322,
#         'lat': 56.898778,
#         'depTime': '18:28:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:27:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Älmhult station',
#         'id': 'A=1@O=Älmhult station@X=14136985@Y=56551426@U=1@L=740000045@',
#         'extId': '740000045',
#         'routeIdx': 5,
#         'lon': 14.136985,
#         'lat': 56.551426,
#         'depTime': '18:50:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:49:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Hässleholm Centralstation',
#         'id': 'A=1@O=Hässleholm Centralstation@X=13763141@Y=56157762@U=1@L=740000006@',
#         'extId': '740000006',
#         'routeIdx': 6,
#         'lon': 13.763141,
#         'lat': 56.157762,
#         'depTime': '19:12:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:11:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 7,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'arrTime': '19:40:00',
#         'arrDate': '2025-01-15',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 8,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '19:52:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|1003|0|1|15012025',
#       'dayOfOperation': '2025-01-15'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Snabbtåg 539',
#      'number': '539',
#      'category': 'JST',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö Centralstation',
#      'directionFlag': '1',
#      'duration': 'PT4H28M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 0,
#   'tripId': 'C-0',
#   'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501151524$202501151952$JST  539$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT4H28M',
#   'rtDuration': 'PT4H28M',
#   'checksum': 'f75d89ef_3'},
#  {'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '16:17:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 9,
#    'prognosisType': 'PROGNOSED',
#    'time': '20:52:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '15. jan t o m 9. jun 2025; utom 8., 9. feb, 1., 2., 16. mar, 26., 27. apr, 1. t o m 4. maj 2025, 17., 18. maj, 5. t o m 8. jun 2025',
#     'sDaysB': '007FFFFFF9FFFFCFFFBFFFFFFFFFCE1FFE7FFFC200'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '16:17:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 9,
#       'prognosisType': 'PROGNOSED',
#       'time': '20:52:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'X2000',
#         'key': 'VX',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'X2000'},
#        {'value': 'Mat 1 klass',
#         'key': 'A1',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Mat 1 klass'},
#        {'value': 'Bistrovagn',
#         'key': 'AD',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Bistrovagn'},
#        {'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'WiFi',
#         'key': 'AW',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'WiFi'},
#        {'value': '2 klass lugn',
#         'key': 'BL',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': '2 klass lugn'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Maträtt',
#         'key': 'SM',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Maträtt'},
#        {'value': '1 klass med extra komfort',
#         'key': 'SU',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': '1 klass med extra komfort'},
#        {'value': 'Kaffebuffé 1 klass',
#         'key': 'SZ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Kaffebuffé 1 klass'}]},
#      'JourneyDetailRef': {'ref': '1|61012|0|1|15012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'SJ',
#         'nameS': '74',
#         'nameN': '74',
#         'nameL': 'SJ',
#         'id': '74'},
#        'name': 'Snabbtåg 541',
#        'internalName': 'Snabbtåg 541',
#        'displayNumber': '541',
#        'num': '541',
#        'line': '541',
#        'lineId': '1074054100001',
#        'catOut': 'JST',
#        'catIn': 'JST',
#        'catCode': '1',
#        'cls': '2',
#        'catOutS': 'JST',
#        'catOutL': 'Snabbtåg',
#        'operatorCode': '74',
#        'operator': 'SJ',
#        'admin': '074___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 9,
#        'matchId': '541;541;30994'}],
#      'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#         'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#         'extId': '740000001',
#         'routeIdx': 0,
#         'lon': 18.058151,
#         'lat': 59.330136,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '16:17:00',
#         'depDate': '2025-01-15',
#         'depDir': 'Malmö Centralstation',
#         'minimumChangeDuration': 'PT20M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#            'key': 'text.realtime.stop.exit.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för påstigande'}]},
#         'name': 'Södertälje Syd station',
#         'id': 'A=1@O=Södertälje Syd station@X=17645367@Y=59162415@U=1@L=740000055@',
#         'extId': '740000055',
#         'routeIdx': 1,
#         'lon': 17.645367,
#         'lat': 59.162415,
#         'depTime': '16:36:00',
#         'depDate': '2025-01-15',
#         'alighting': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Norrköping Centralstation',
#         'id': 'A=1@O=Norrköping Centralstation@X=16183343@Y=58596625@U=1@L=740000007@',
#         'extId': '740000007',
#         'routeIdx': 2,
#         'lon': 16.183343,
#         'lat': 58.596625,
#         'depTime': '17:38:00',
#         'depDate': '2025-01-15',
#         'arrTime': '17:37:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Linköping Centralstation',
#         'id': 'A=1@O=Linköping Centralstation@X=15624960@Y=58416634@U=1@L=740000009@',
#         'extId': '740000009',
#         'routeIdx': 3,
#         'lon': 15.62496,
#         'lat': 58.416634,
#         'depTime': '18:05:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:03:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Mjölby station',
#         'id': 'A=1@O=Mjölby station@X=15131992@Y=58322984@U=1@L=740000180@',
#         'extId': '740000180',
#         'routeIdx': 4,
#         'lon': 15.131992,
#         'lat': 58.322984,
#         'depTime': '18:21:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:20:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Nässjö Centralstation',
#         'id': 'A=1@O=Nässjö Centralstation@X=14693983@Y=57652443@U=1@L=740000140@',
#         'extId': '740000140',
#         'routeIdx': 5,
#         'lon': 14.693983,
#         'lat': 57.652443,
#         'depTime': '18:58:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:57:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Alvesta station',
#         'id': 'A=1@O=Alvesta station@X=14556322@Y=56898778@U=1@L=740000004@',
#         'extId': '740000004',
#         'routeIdx': 6,
#         'lon': 14.556322,
#         'lat': 56.898778,
#         'depTime': '19:32:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:31:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Hässleholm Centralstation',
#         'id': 'A=1@O=Hässleholm Centralstation@X=13763141@Y=56157762@U=1@L=740000006@',
#         'extId': '740000006',
#         'routeIdx': 7,
#         'lon': 13.763141,
#         'lat': 56.157762,
#         'depTime': '20:12:00',
#         'depDate': '2025-01-15',
#         'arrTime': '20:11:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 8,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'depTime': '20:41:00',
#         'depDate': '2025-01-15',
#         'arrTime': '20:40:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 9,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '20:52:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|61012|0|1|15012025',
#       'dayOfOperation': '2025-01-15'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Snabbtåg 541',
#      'number': '541',
#      'category': 'JST',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö Centralstation',
#      'directionFlag': '1',
#      'duration': 'PT4H35M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 1,
#   'tripId': 'C-1',
#   'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501151617$202501152052$JST  541$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT4H35M',
#   'rtDuration': 'PT4H35M',
#   'checksum': '070cb9bb_3'},
#  {'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '16:20:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 9,
#    'prognosisType': 'PROGNOSED',
#    'time': '21:15:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '15. jan t o m 25. apr 2025; utom 8., 9. feb, 1., 2. mar',
#     'sDaysB': '007FFFFFF9FFFFCFFFFFFFFFFFFFC0000000000000'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '16:20:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 9,
#       'prognosisType': 'PROGNOSED',
#       'time': '21:15:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Krog',
#         'key': 'SG',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 9,
#         'txtN': 'Krog'}]},
#      'JourneyDetailRef': {'ref': '1|139457|0|1|15012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'Snälltåget',
#         'nameS': '380',
#         'nameN': '380',
#         'nameL': 'Snälltåget',
#         'id': '380'},
#        'name': 'Tåg 3943',
#        'internalName': 'Tåg 3943',
#        'displayNumber': '3943',
#        'num': '3943',
#        'line': '3943',
#        'lineId': '1380394300002',
#        'catOut': 'JBL',
#        'catIn': 'JBL',
#        'catCode': '2',
#        'cls': '4',
#        'catOutS': 'JBL',
#        'catOutL': 'Tåg',
#        'operatorCode': '380',
#        'operator': 'Snälltåget',
#        'admin': '380___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 9,
#        'matchId': '3943;3943;35093'}],
#      'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#         'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#         'extId': '740000001',
#         'routeIdx': 0,
#         'lon': 18.058151,
#         'lat': 59.330136,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '16:20:00',
#         'depDate': '2025-01-15',
#         'depDir': 'Malmö Centralstation',
#         'minimumChangeDuration': 'PT20M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#            'key': 'text.realtime.stop.exit.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för påstigande'}]},
#         'name': 'Södertälje Syd station',
#         'id': 'A=1@O=Södertälje Syd station@X=17645367@Y=59162415@U=1@L=740000055@',
#         'extId': '740000055',
#         'routeIdx': 1,
#         'lon': 17.645367,
#         'lat': 59.162415,
#         'depTime': '16:40:00',
#         'depDate': '2025-01-15',
#         'alighting': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Norrköping Centralstation',
#         'id': 'A=1@O=Norrköping Centralstation@X=16183343@Y=58596625@U=1@L=740000007@',
#         'extId': '740000007',
#         'routeIdx': 2,
#         'lon': 16.183343,
#         'lat': 58.596625,
#         'depTime': '17:45:00',
#         'depDate': '2025-01-15',
#         'arrTime': '17:45:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Linköping Centralstation',
#         'id': 'A=1@O=Linköping Centralstation@X=15624960@Y=58416634@U=1@L=740000009@',
#         'extId': '740000009',
#         'routeIdx': 3,
#         'lon': 15.62496,
#         'lat': 58.416634,
#         'depTime': '18:10:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:10:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Nässjö Centralstation',
#         'id': 'A=1@O=Nässjö Centralstation@X=14693983@Y=57652443@U=1@L=740000140@',
#         'extId': '740000140',
#         'routeIdx': 4,
#         'lon': 14.693983,
#         'lat': 57.652443,
#         'depTime': '19:05:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:05:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Alvesta station',
#         'id': 'A=1@O=Alvesta station@X=14556322@Y=56898778@U=1@L=740000004@',
#         'extId': '740000004',
#         'routeIdx': 5,
#         'lon': 14.556322,
#         'lat': 56.898778,
#         'depTime': '19:42:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:42:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT9M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Hässleholm Centralstation',
#         'id': 'A=1@O=Hässleholm Centralstation@X=13763141@Y=56157762@U=1@L=740000006@',
#         'extId': '740000006',
#         'routeIdx': 6,
#         'lon': 13.763141,
#         'lat': 56.157762,
#         'arrTime': '20:25:00',
#         'arrDate': '2025-01-15',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Eslöv station',
#         'id': 'A=1@O=Eslöv station@X=13305491@Y=55837719@U=1@L=740000260@',
#         'extId': '740000260',
#         'routeIdx': 7,
#         'lon': 13.305491,
#         'lat': 55.837719,
#         'arrTime': '20:46:00',
#         'arrDate': '2025-01-15',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 8,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'arrTime': '21:00:00',
#         'arrDate': '2025-01-15',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 9,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '21:15:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|139457|0|1|15012025',
#       'dayOfOperation': '2025-01-15'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Tåg 3943',
#      'number': '3943',
#      'category': 'JBL',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö Centralstation',
#      'directionFlag': '2',
#      'duration': 'PT4H55M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 2,
#   'tripId': 'C-2',
#   'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501151620$202501152115$JBL 3943$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT4H55M',
#   'rtDuration': 'PT4H55M',
#   'checksum': '2f4923b1_3'},
#  {'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '17:26:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 8,
#    'prognosisType': 'PROGNOSED',
#    'time': '21:52:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'inte varje dag',
#     'sDaysI': '15. jan t o m 9. jun 2025 mån - fre, sön; utom 9. feb, 2., 16. mar, 18. apr, 27. t o m 29. apr 2025, 1. t o m 4. maj 2025, 6., 8. jun',
#     'sDaysB': '003F7EFDF9F7EFCFBF3EFDFBF7CFC21F7EFDFBE200'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '17:26:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 8,
#       'prognosisType': 'PROGNOSED',
#       'time': '21:52:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'X2000',
#         'key': 'VX',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'X2000'},
#        {'value': 'Mat 1 klass',
#         'key': 'A1',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Mat 1 klass'},
#        {'value': 'Bistrovagn',
#         'key': 'AD',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Bistrovagn'},
#        {'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'Rullstolslyft',
#         'key': 'AN',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Rullstolslyft'},
#        {'value': 'WiFi',
#         'key': 'AW',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'WiFi'},
#        {'value': '2 klass lugn',
#         'key': 'BL',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': '2 klass lugn'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Maträtt',
#         'key': 'SM',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Maträtt'},
#        {'value': '1 klass med extra komfort',
#         'key': 'SU',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': '1 klass med extra komfort'},
#        {'value': 'Kaffebuffé 1 klass',
#         'key': 'SZ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 8,
#         'txtN': 'Kaffebuffé 1 klass'}]},
#      'JourneyDetailRef': {'ref': '1|135138|0|1|15012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'SJ',
#         'nameS': '74',
#         'nameN': '74',
#         'nameL': 'SJ',
#         'id': '74'},
#        'name': 'Snabbtåg 543',
#        'internalName': 'Snabbtåg 543',
#        'displayNumber': '543',
#        'num': '543',
#        'line': '543',
#        'lineId': '1074054300001',
#        'catOut': 'JST',
#        'catIn': 'JST',
#        'catCode': '1',
#        'cls': '2',
#        'catOutS': 'JST',
#        'catOutL': 'Snabbtåg',
#        'operatorCode': '74',
#        'operator': 'SJ',
#        'admin': '074___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 8,
#        'matchId': '543;543;9307'}],
#      'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#         'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#         'extId': '740000001',
#         'routeIdx': 0,
#         'lon': 18.058151,
#         'lat': 59.330136,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '17:26:00',
#         'depDate': '2025-01-15',
#         'depDir': 'Malmö Centralstation',
#         'minimumChangeDuration': 'PT20M'},
#        {'name': 'Norrköping Centralstation',
#         'id': 'A=1@O=Norrköping Centralstation@X=16183343@Y=58596625@U=1@L=740000007@',
#         'extId': '740000007',
#         'routeIdx': 1,
#         'lon': 16.183343,
#         'lat': 58.596625,
#         'depTime': '18:41:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:40:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Linköping Centralstation',
#         'id': 'A=1@O=Linköping Centralstation@X=15624960@Y=58416634@U=1@L=740000009@',
#         'extId': '740000009',
#         'routeIdx': 2,
#         'lon': 15.62496,
#         'lat': 58.416634,
#         'depTime': '19:06:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:04:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Tranås station',
#         'id': 'A=1@O=Tranås station@X=14975022@Y=58037963@U=1@L=740000041@',
#         'extId': '740000041',
#         'routeIdx': 3,
#         'lon': 14.975022,
#         'lat': 58.037963,
#         'depTime': '19:34:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:34:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT5M'},
#        {'name': 'Nässjö Centralstation',
#         'id': 'A=1@O=Nässjö Centralstation@X=14693983@Y=57652443@U=1@L=740000140@',
#         'extId': '740000140',
#         'routeIdx': 4,
#         'lon': 14.693983,
#         'lat': 57.652443,
#         'depTime': '19:58:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:57:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Alvesta station',
#         'id': 'A=1@O=Alvesta station@X=14556322@Y=56898778@U=1@L=740000004@',
#         'extId': '740000004',
#         'routeIdx': 5,
#         'lon': 14.556322,
#         'lat': 56.898778,
#         'depTime': '20:32:00',
#         'depDate': '2025-01-15',
#         'arrTime': '20:31:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Hässleholm Centralstation',
#         'id': 'A=1@O=Hässleholm Centralstation@X=13763141@Y=56157762@U=1@L=740000006@',
#         'extId': '740000006',
#         'routeIdx': 6,
#         'lon': 13.763141,
#         'lat': 56.157762,
#         'depTime': '21:12:00',
#         'depDate': '2025-01-15',
#         'arrTime': '21:11:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#            'key': 'text.realtime.stop.entry.disabled',
#            'type': 'R',
#            'txtN': 'Stannar endast för avstigande'}]},
#         'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 7,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'arrTime': '21:40:00',
#         'arrDate': '2025-01-15',
#         'boarding': False,
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 8,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrPrognosisType': 'PROGNOSED',
#         'arrTime': '21:52:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|135138|0|1|15012025',
#       'dayOfOperation': '2025-01-15'},
#      'id': '0',
#      'idx': 0,
#      'name': 'Snabbtåg 543',
#      'number': '543',
#      'category': 'JST',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Malmö Centralstation',
#      'directionFlag': '1',
#      'duration': 'PT4H26M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 3,
#   'tripId': 'C-3',
#   'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501151726$202501152152$JST  543$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT4H26M',
#   'rtDuration': 'PT4H26M',
#   'checksum': '80c0ec45_3'},
#  {'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '17:34:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Malmö Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#    'extId': '740000003',
#    'lon': 13.00091,
#    'lat': 55.609456,
#    'routeIdx': 7,
#    'prognosisType': 'PROGNOSED',
#    'time': '22:42:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#     'planningPeriodEnd': '2025-06-15',
#     'sDaysR': 'mån - fre, sön',
#     'sDaysI': 'utom 2., 16. mar, 16. t o m 27. apr 2025, 9. maj, 6. t o m 9. jun 2025',
#     'sDaysB': '003F7EFDFBF7EFCFBF3EFDFBF7000FBE7EFDFBE1E8'}],
#   'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'routeIdx': 0,
#       'prognosisType': 'PROGNOSED',
#       'time': '17:34:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT20M'},
#      'Destination': {'name': 'Malmö Centralstation',
#       'type': 'ST',
#       'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#       'extId': '740000003',
#       'lon': 13.00091,
#       'lat': 55.609456,
#       'routeIdx': 7,
#       'prognosisType': 'PROGNOSED',
#       'time': '22:42:00',
#       'date': '2025-01-15',
#       'minimumChangeDuration': 'PT15M'},
#      'Notes': {'Note': [{'value': 'Endast 2 klass',
#         'key': 'AA',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 7,
#         'txtN': 'Endast 2 klass'},
#        {'value': 'Bistrovagn',
#         'key': 'AD',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 5,
#         'txtN': 'Bistrovagn'},
#        {'value': 'Obligatorisk platsbokning',
#         'key': 'AF',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 7,
#         'txtN': 'Obligatorisk platsbokning'},
#        {'value': 'EU förordning 2021/782',
#         'key': 'EJ',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 7,
#         'txtN': 'EU förordning 2021/782'},
#        {'value': 'Sov- och liggvagn',
#         'key': 'SL',
#         'type': 'A',
#         'routeIdxFrom': 0,
#         'routeIdxTo': 7,
#         'txtN': 'Sov- och liggvagn'}]},
#      'JourneyDetailRef': {'ref': '1|109611|0|1|15012025'},
#      'JourneyStatus': 'P',
#      'Product': [{'icon': {'res': 'prod_gen'},
#        'operatorInfo': {'name': 'SJ',
#         'nameS': '74',
#         'nameN': '74',
#         'nameL': 'SJ',
#         'id': '74'},
#        'name': 'EuroNight 345',
#        'internalName': 'EuroNight 345',
#        'displayNumber': '345',
#        'num': '345',
#        'line': '345',
#        'lineId': '1074034500001',
#        'catOut': 'JEN',
#        'catIn': 'JEN',
#        'catCode': '2',
#        'cls': '4',
#        'catOutS': 'JEN',
#        'catOutL': 'EuroNight',
#        'operatorCode': '74',
#        'operator': 'SJ',
#        'admin': '074___',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 7,
#        'matchId': '345;345;62819'}],
#      'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#         'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#         'extId': '740000001',
#         'routeIdx': 0,
#         'lon': 18.058151,
#         'lat': 59.330136,
#         'depPrognosisType': 'PROGNOSED',
#         'depTime': '17:34:00',
#         'depDate': '2025-01-15',
#         'depDir': 'Berlin Hbf (Tyskland)',
#         'minimumChangeDuration': 'PT20M'},
#        {'name': 'Norrköping Centralstation',
#         'id': 'A=1@O=Norrköping Centralstation@X=16183343@Y=58596625@U=1@L=740000007@',
#         'extId': '740000007',
#         'routeIdx': 1,
#         'lon': 16.183343,
#         'lat': 58.596625,
#         'depTime': '18:59:00',
#         'depDate': '2025-01-15',
#         'arrTime': '18:58:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Linköping Centralstation',
#         'id': 'A=1@O=Linköping Centralstation@X=15624960@Y=58416634@U=1@L=740000009@',
#         'extId': '740000009',
#         'routeIdx': 2,
#         'lon': 15.62496,
#         'lat': 58.416634,
#         'depTime': '19:28:00',
#         'depDate': '2025-01-15',
#         'arrTime': '19:26:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Nässjö Centralstation',
#         'id': 'A=1@O=Nässjö Centralstation@X=14693983@Y=57652443@U=1@L=740000140@',
#         'extId': '740000140',
#         'routeIdx': 3,
#         'lon': 14.693983,
#         'lat': 57.652443,
#         'depTime': '20:26:00',
#         'depDate': '2025-01-15',
#         'arrTime': '20:25:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Alvesta station',
#         'id': 'A=1@O=Alvesta station@X=14556322@Y=56898778@U=1@L=740000004@',
#         'extId': '740000004',
#         'routeIdx': 4,
#         'lon': 14.556322,
#         'lat': 56.898778,
#         'depTime': '21:08:00',
#         'depDate': '2025-01-15',
#         'arrTime': '21:07:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT9M'},
#        {'name': 'Hässleholm Centralstation',
#         'id': 'A=1@O=Hässleholm Centralstation@X=13763141@Y=56157762@U=1@L=740000006@',
#         'extId': '740000006',
#         'routeIdx': 5,
#         'lon': 13.763141,
#         'lat': 56.157762,
#         'depTime': '21:54:00',
#         'depDate': '2025-01-15',
#         'arrTime': '21:54:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Lund Centralstation',
#         'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#         'extId': '740000120',
#         'routeIdx': 6,
#         'lon': 13.186897,
#         'lat': 55.708094,
#         'depTime': '22:29:00',
#         'depDate': '2025-01-15',
#         'arrTime': '22:29:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT10M'},
#        {'name': 'Malmö Centralstation',
#         'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#         'extId': '740000003',
#         'routeIdx': 7,
#         'lon': 13.00091,
#         'lat': 55.609456,
#         'arrTime': '22:42:00',
#         'arrDate': '2025-01-15',
#         'minimumChangeDuration': 'PT15M'}]},
#      'JourneyDetail': {'ref': '1|109611|0|1|15012025',
#       'dayOfOperation': '2025-01-15'},
#      'id': '0',
#      'idx': 0,
#      'name': 'EuroNight 345',
#      'number': '345',
#      'category': 'JEN',
#      'type': 'JNY',
#      'reachable': True,
#      'waitingState': 'UNDEF',
#      'direction': 'Berlin Hbf (Tyskland)',
#      'directionFlag': '1',
#      'duration': 'PT5H8M'}]},
#   'calculation': 'INITIAL',
#   'TripStatus': {'hintCode': 0},
#   'idx': 4,
#   'tripId': 'C-4',
#   'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501151734$202501152242$JEN  345$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#   'duration': 'PT5H8M',
#   'rtDuration': 'PT5H8M',
#   'checksum': 'c2dbe44a_3'}]

# %%
def get_trips(origin_id=740000001, destination_id=740098001):
    """origing_id and destination_id can be found from Stop lookup API"""
    url = f"https://api.resrobot.se/v2.1/trip?format=json&originId={origin_id}&destId={destination_id}&passlist=true&showPassingPoints=true&accessId={API_KEY}"

    try:
        response = requests.get(url)
        response.raise_for_status()

        return response.json()
    except requests.exceptions.RequestException as err:
        print(f"Network or HTTP error: {err}")


result = get_trips()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
example_trip = result["Trip"][0]
example_trip
# Out:
# {'Origin': {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '14:07:00',
#   'date': '2025-01-15',
#   'minimumChangeDuration': 'PT20M'},
#  'Destination': {'name': 'Göteborg Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'routeIdx': 4,
#   'prognosisType': 'PROGNOSED',
#   'time': '17:41:00',
#   'date': '2025-01-15',
#   'minimumChangeDuration': 'PT15M'},
#  'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#    'planningPeriodEnd': '2025-06-15',
#    'sDaysR': 'mån - ons',
#    'sDaysI': '20. mar t o m 27. apr 2025 mån - fre, sön; 8. t o m 25. maj 2025 mån - fre, sön; utom 3. feb t o m 12. mar 2025, 18. t o m 21. apr 2025, 18. maj, 10., 11. jun; och 16. jan t o m 2. feb 2025, 26. apr, 5., 7. jun',
#    'sDaysB': '007FFFFF00000000003EFDFBF7C3FE1F7E7DE1EA00'}],
#  'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#      'extId': '740000001',
#      'lon': 18.058151,
#      'lat': 59.330136,
#      'routeIdx': 0,
#      'prognosisType': 'PROGNOSED',
#      'time': '14:07:00',
#      'date': '2025-01-15',
#      'minimumChangeDuration': 'PT20M'},
#     'Destination': {'name': 'Göteborg Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#      'extId': '740000002',
#      'lon': 11.973479,
#      'lat': 57.708895,
#      'routeIdx': 4,
#      'prognosisType': 'PROGNOSED',
#      'time': '17:41:00',
#      'date': '2025-01-15',
#      'minimumChangeDuration': 'PT15M'},
#     'Notes': {'Note': [{'value': 'X2000',
#        'key': 'VX',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'X2000'},
#       {'value': 'Mat 1 klass',
#        'key': 'A1',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Mat 1 klass'},
#       {'value': 'Bistrovagn',
#        'key': 'AD',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Bistrovagn'},
#       {'value': 'Obligatorisk platsbokning',
#        'key': 'AF',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Obligatorisk platsbokning'},
#       {'value': 'Rullstolslyft',
#        'key': 'AN',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Rullstolslyft'},
#       {'value': 'WiFi',
#        'key': 'AW',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'WiFi'},
#       {'value': '2 klass lugn',
#        'key': 'BL',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': '2 klass lugn'},
#       {'value': 'EU förordning 2021/782',
#        'key': 'EJ',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'EU förordning 2021/782'},
#       {'value': 'Maträtt',
#        'key': 'SM',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Maträtt'},
#       {'value': '1 klass med extra komfort',
#        'key': 'SU',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': '1 klass med extra komfort'},
#       {'value': 'Kaffebuffé 1 klass',
#        'key': 'SZ',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 4,
#        'txtN': 'Kaffebuffé 1 klass'}]},
#     'JourneyDetailRef': {'ref': '1|70477|0|1|15012025'},
#     'JourneyStatus': 'P',
#     'Product': [{'icon': {'res': 'prod_gen'},
#       'operatorInfo': {'name': 'SJ',
#        'nameS': '74',
#        'nameN': '74',
#        'nameL': 'SJ',
#        'id': '74'},
#       'name': 'Snabbtåg 437',
#       'internalName': 'Snabbtåg 437',
#       'displayNumber': '437',
#       'num': '437',
#       'line': '437',
#       'lineId': '1074043700001',
#       'catOut': 'JST',
#       'catIn': 'JST',
#       'catCode': '1',
#       'cls': '2',
#       'catOutS': 'JST',
#       'catOutL': 'Snabbtåg',
#       'operatorCode': '74',
#       'operator': 'SJ',
#       'admin': '074___',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 4,
#       'matchId': '437;437;50056'}],
#     'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#        'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#        'extId': '740000001',
#        'routeIdx': 0,
#        'lon': 18.058151,
#        'lat': 59.330136,
#        'depPrognosisType': 'PROGNOSED',
#        'depTime': '14:07:00',
#        'depDate': '2025-01-15',
#        'depDir': 'Göteborg Centralstation',
#        'minimumChangeDuration': 'PT20M'},
#       {'name': 'Katrineholm Centralstation',
#        'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#        'extId': '740000166',
#        'routeIdx': 1,
#        'lon': 16.208324,
#        'lat': 58.996591,
#        'depTime': '15:00:00',
#        'depDate': '2025-01-15',
#        'arrTime': '14:59:00',
#        'arrDate': '2025-01-15',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Skövde Centralstation',
#        'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#        'extId': '740000008',
#        'routeIdx': 2,
#        'lon': 13.853195,
#        'lat': 58.390898,
#        'depTime': '16:17:00',
#        'depDate': '2025-01-15',
#        'arrTime': '16:17:00',
#        'arrDate': '2025-01-15',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Herrljunga station',
#        'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#        'extId': '740000040',
#        'routeIdx': 3,
#        'lon': 13.021279,
#        'lat': 58.079188,
#        'depTime': '16:45:00',
#        'depDate': '2025-01-15',
#        'arrTime': '16:45:00',
#        'arrDate': '2025-01-15',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Göteborg Centralstation',
#        'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#        'extId': '740000002',
#        'routeIdx': 4,
#        'lon': 11.973479,
#        'lat': 57.708895,
#        'arrPrognosisType': 'PROGNOSED',
#        'arrTime': '17:41:00',
#        'arrDate': '2025-01-15',
#        'minimumChangeDuration': 'PT15M'}]},
#     'JourneyDetail': {'ref': '1|70477|0|1|15012025',
#      'dayOfOperation': '2025-01-15'},
#     'id': '0',
#     'idx': 0,
#     'name': 'Snabbtåg 437',
#     'number': '437',
#     'category': 'JST',
#     'type': 'JNY',
#     'reachable': True,
#     'waitingState': 'UNDEF',
#     'direction': 'Göteborg Centralstation',
#     'directionFlag': '1',
#     'duration': 'PT3H34M'}]},
#  'calculation': 'INITIAL',
#  'TripStatus': {'hintCode': 0},
#  'idx': 0,
#  'tripId': 'C-0',
#  'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Göteborg Centralstation@L=740000002@a=128@$202501151407$202501151741$JST  437$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#  'duration': 'PT3H34M',
#  'rtDuration': 'PT3H34M',
#  'checksum': '0ffb42a3_3'}

# %%
example_trip['Origin']
# Out:
# {'name': 'Stockholm Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#  'extId': '740000001',
#  'lon': 18.058151,
#  'lat': 59.330136,
#  'routeIdx': 0,
#  'prognosisType': 'PROGNOSED',
#  'time': '14:07:00',
#  'date': '2025-01-15',
#  'minimumChangeDuration': 'PT20M'}

# %%
example_trip["Destination"]
# Out:
# {'name': 'Göteborg Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#  'extId': '740000002',
#  'lon': 11.973479,
#  'lat': 57.708895,
#  'routeIdx': 4,
#  'prognosisType': 'PROGNOSED',
#  'time': '17:41:00',
#  'date': '2025-01-15',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip["TripStatus"]
# Out:
# {'hintCode': 0}

# %%
example_trip.keys()
# Out:
# dict_keys(['Origin', 'Destination', 'ServiceDays', 'LegList', 'calculation', 'TripStatus', 'idx', 'tripId', 'ctxRecon', 'duration', 'rtDuration', 'checksum'])

# %%
example_trip["LegList"]["Leg"]
# Out:
# [{'Origin': {'name': 'Stockholm Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#    'extId': '740000001',
#    'lon': 18.058151,
#    'lat': 59.330136,
#    'routeIdx': 0,
#    'prognosisType': 'PROGNOSED',
#    'time': '14:07:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT20M'},
#   'Destination': {'name': 'Göteborg Centralstation',
#    'type': 'ST',
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#    'extId': '740000002',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'routeIdx': 4,
#    'prognosisType': 'PROGNOSED',
#    'time': '17:41:00',
#    'date': '2025-01-15',
#    'minimumChangeDuration': 'PT15M'},
#   'Notes': {'Note': [{'value': 'X2000',
#      'key': 'VX',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'X2000'},
#     {'value': 'Mat 1 klass',
#      'key': 'A1',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Mat 1 klass'},
#     {'value': 'Bistrovagn',
#      'key': 'AD',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Bistrovagn'},
#     {'value': 'Obligatorisk platsbokning',
#      'key': 'AF',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Obligatorisk platsbokning'},
#     {'value': 'Rullstolslyft',
#      'key': 'AN',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Rullstolslyft'},
#     {'value': 'WiFi',
#      'key': 'AW',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'WiFi'},
#     {'value': '2 klass lugn',
#      'key': 'BL',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': '2 klass lugn'},
#     {'value': 'EU förordning 2021/782',
#      'key': 'EJ',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'EU förordning 2021/782'},
#     {'value': 'Maträtt',
#      'key': 'SM',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Maträtt'},
#     {'value': '1 klass med extra komfort',
#      'key': 'SU',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': '1 klass med extra komfort'},
#     {'value': 'Kaffebuffé 1 klass',
#      'key': 'SZ',
#      'type': 'A',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 4,
#      'txtN': 'Kaffebuffé 1 klass'}]},
#   'JourneyDetailRef': {'ref': '1|70477|0|1|15012025'},
#   'JourneyStatus': 'P',
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'SJ',
#      'nameS': '74',
#      'nameN': '74',
#      'nameL': 'SJ',
#      'id': '74'},
#     'name': 'Snabbtåg 437',
#     'internalName': 'Snabbtåg 437',
#     'displayNumber': '437',
#     'num': '437',
#     'line': '437',
#     'lineId': '1074043700001',
#     'catOut': 'JST',
#     'catIn': 'JST',
#     'catCode': '1',
#     'cls': '2',
#     'catOutS': 'JST',
#     'catOutL': 'Snabbtåg',
#     'operatorCode': '74',
#     'operator': 'SJ',
#     'admin': '074___',
#     'routeIdxFrom': 0,
#     'routeIdxTo': 4,
#     'matchId': '437;437;50056'}],
#   'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#      'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#      'extId': '740000001',
#      'routeIdx': 0,
#      'lon': 18.058151,
#      'lat': 59.330136,
#      'depPrognosisType': 'PROGNOSED',
#      'depTime': '14:07:00',
#      'depDate': '2025-01-15',
#      'depDir': 'Göteborg Centralstation',
#      'minimumChangeDuration': 'PT20M'},
#     {'name': 'Katrineholm Centralstation',
#      'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#      'extId': '740000166',
#      'routeIdx': 1,
#      'lon': 16.208324,
#      'lat': 58.996591,
#      'depTime': '15:00:00',
#      'depDate': '2025-01-15',
#      'arrTime': '14:59:00',
#      'arrDate': '2025-01-15',
#      'minimumChangeDuration': 'PT10M'},
#     {'name': 'Skövde Centralstation',
#      'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#      'extId': '740000008',
#      'routeIdx': 2,
#      'lon': 13.853195,
#      'lat': 58.390898,
#      'depTime': '16:17:00',
#      'depDate': '2025-01-15',
#      'arrTime': '16:17:00',
#      'arrDate': '2025-01-15',
#      'minimumChangeDuration': 'PT10M'},
#     {'name': 'Herrljunga station',
#      'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#      'extId': '740000040',
#      'routeIdx': 3,
#      'lon': 13.021279,
#      'lat': 58.079188,
#      'depTime': '16:45:00',
#      'depDate': '2025-01-15',
#      'arrTime': '16:45:00',
#      'arrDate': '2025-01-15',
#      'minimumChangeDuration': 'PT8M'},
#     {'name': 'Göteborg Centralstation',
#      'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#      'extId': '740000002',
#      'routeIdx': 4,
#      'lon': 11.973479,
#      'lat': 57.708895,
#      'arrPrognosisType': 'PROGNOSED',
#      'arrTime': '17:41:00',
#      'arrDate': '2025-01-15',
#      'minimumChangeDuration': 'PT15M'}]},
#   'JourneyDetail': {'ref': '1|70477|0|1|15012025',
#    'dayOfOperation': '2025-01-15'},
#   'id': '0',
#   'idx': 0,
#   'name': 'Snabbtåg 437',
#   'number': '437',
#   'category': 'JST',
#   'type': 'JNY',
#   'reachable': True,
#   'waitingState': 'UNDEF',
#   'direction': 'Göteborg Centralstation',
#   'directionFlag': '1',
#   'duration': 'PT3H34M'}]

# %%
example_trip["LegList"]["Leg"][0].keys()
# Out:
# dict_keys(['Origin', 'Destination', 'Notes', 'JourneyDetailRef', 'JourneyStatus', 'Product', 'Stops', 'JourneyDetail', 'id', 'idx', 'name', 'number', 'category', 'type', 'reachable', 'waitingState', 'direction', 'directionFlag', 'duration'])

# %%
example_trip["LegList"]["Leg"][0]["Stops"]["Stop"]
# Out:
# [{'name': 'Stockholm Centralstation',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'routeIdx': 0,
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'depPrognosisType': 'PROGNOSED',
#   'depTime': '14:07:00',
#   'depDate': '2025-01-15',
#   'depDir': 'Göteborg Centralstation',
#   'minimumChangeDuration': 'PT20M'},
#  {'name': 'Katrineholm Centralstation',
#   'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#   'extId': '740000166',
#   'routeIdx': 1,
#   'lon': 16.208324,
#   'lat': 58.996591,
#   'depTime': '15:00:00',
#   'depDate': '2025-01-15',
#   'arrTime': '14:59:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Skövde Centralstation',
#   'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#   'extId': '740000008',
#   'routeIdx': 2,
#   'lon': 13.853195,
#   'lat': 58.390898,
#   'depTime': '16:17:00',
#   'depDate': '2025-01-15',
#   'arrTime': '16:17:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Herrljunga station',
#   'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#   'extId': '740000040',
#   'routeIdx': 3,
#   'lon': 13.021279,
#   'lat': 58.079188,
#   'depTime': '16:45:00',
#   'depDate': '2025-01-15',
#   'arrTime': '16:45:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Göteborg Centralstation',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'routeIdx': 4,
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'arrPrognosisType': 'PROGNOSED',
#   'arrTime': '17:41:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT15M'}]

# %%
example_stop = example_trip["LegList"]["Leg"][0]["Stops"]["Stop"]
example_stop
# Out:
# [{'name': 'Stockholm Centralstation',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'routeIdx': 0,
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'depPrognosisType': 'PROGNOSED',
#   'depTime': '14:07:00',
#   'depDate': '2025-01-15',
#   'depDir': 'Göteborg Centralstation',
#   'minimumChangeDuration': 'PT20M'},
#  {'name': 'Katrineholm Centralstation',
#   'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#   'extId': '740000166',
#   'routeIdx': 1,
#   'lon': 16.208324,
#   'lat': 58.996591,
#   'depTime': '15:00:00',
#   'depDate': '2025-01-15',
#   'arrTime': '14:59:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Skövde Centralstation',
#   'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#   'extId': '740000008',
#   'routeIdx': 2,
#   'lon': 13.853195,
#   'lat': 58.390898,
#   'depTime': '16:17:00',
#   'depDate': '2025-01-15',
#   'arrTime': '16:17:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Herrljunga station',
#   'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#   'extId': '740000040',
#   'routeIdx': 3,
#   'lon': 13.021279,
#   'lat': 58.079188,
#   'depTime': '16:45:00',
#   'depDate': '2025-01-15',
#   'arrTime': '16:45:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Göteborg Centralstation',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'routeIdx': 4,
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'arrPrognosisType': 'PROGNOSED',
#   'arrTime': '17:41:00',
#   'arrDate': '2025-01-15',
#   'minimumChangeDuration': 'PT15M'}]

# %%
[{stop.get("name"): stop.get("arrTime")} for stop in example_stop]
# Out:
# [{'Stockholm Centralstation': None},
#  {'Katrineholm Centralstation': '14:59:00'},
#  {'Skövde Centralstation': '16:17:00'},
#  {'Herrljunga station': '16:45:00'},
#  {'Göteborg Centralstation': '17:41:00'}]

# %% [markdown]
# ## Stop Look Up to find API

# %%
location = "göteborg"
url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"
response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['stopLocationOrCoordLocation', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'requestId'])

# %%
result["stopLocationOrCoordLocation"]
# Out:
# [{'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '4'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '256'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=GÖTEBORG@X=11973479@Y=57708895@U=1@L=740098001@B=1@p=1736935053@',
#    'extId': '740098001',
#    'name': 'GÖTEBORG',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'weight': 15373,
#    'products': 222,
#    'meta': True,
#    'minimumChangeDuration': 'PT26M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '4'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@B=1@p=1736935053@',
#    'extId': '740000002',
#    'name': 'Göteborg Centralstation',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'weight': 9530,
#    'products': 222,
#    'minimumChangeDuration': 'PT15M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Sävenäs lokstation@X=12021077@Y=57725993@U=1@L=740016365@B=1@p=1736935053@',
#    'extId': '740016365',
#    'name': 'Göteborg Sävenäs lokstation',
#    'lon': 12.021077,
#    'lat': 57.725993,
#    'weight': 117,
#    'products': 128,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=GÖTEBORG GAMLESTADEN@X=12004411@Y=57729148@U=1@L=740098526@B=1@p=1736935053@',
#    'extId': '740098526',
#    'name': 'GÖTEBORG GAMLESTADEN',
#    'lon': 12.004411,
#    'lat': 57.729148,
#    'weight': 7983,
#    'products': 80,
#    'meta': True,
#    'minimumChangeDuration': 'PT26M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742@U=1@L=740015578@B=1@p=1736935053@',
#    'extId': '740015578',
#    'name': 'Göteborg Korsvägen',
#    'lon': 11.986918,
#    'lat': 57.696742,
#    'weight': 5867,
#    'products': 200,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Kungsportsplatsen@X=11969748@Y=57704023@U=1@L=740016358@B=1@p=1736935053@',
#    'extId': '740016358',
#    'name': 'Göteborg Kungsportsplatsen',
#    'lon': 11.969748,
#    'lat': 57.704023,
#    'weight': 5867,
#    'products': 200,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '256'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Stenpiren@X=11957424@Y=57705803@U=1@L=740072430@B=1@p=1736935053@',
#    'extId': '740072430',
#    'name': 'Göteborg Stenpiren',
#    'lon': 11.957424,
#    'lat': 57.705803,
#    'weight': 4834,
#    'products': 448,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '512'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Eketrägatan@X=11910285@Y=57716275@U=1@L=740025624@B=1@p=1736935053@',
#    'extId': '740025624',
#    'name': 'Göteborg Eketrägatan',
#    'lon': 11.910285,
#    'lat': 57.716275,
#    'weight': 4701,
#    'products': 704,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '512'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Vårväderstorget@X=11893097@Y=57713084@U=1@L=740025707@B=1@p=1736935053@',
#    'extId': '740025707',
#    'name': 'Göteborg Vårväderstorget',
#    'lon': 11.893097,
#    'lat': 57.713084,
#    'weight': 4701,
#    'products': 704,
#    'minimumChangeDuration': 'PT3M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Axel Dahlströms torg@X=11927445@Y=57672435@U=1@L=740025608@B=1@p=1736935053@',
#    'extId': '740025608',
#    'name': 'Göteborg Axel Dahlströms torg',
#    'lon': 11.927445,
#    'lat': 57.672435,
#    'weight': 4676,
#    'products': 192,
#    'minimumChangeDuration': 'PT3M'}}]

# %%
stop_locations =result["stopLocationOrCoordLocation"]
len(stop_locations)
# Out:
# 10

# %%
stop_locations[0]["StopLocation"].keys()
# Out:
# dict_keys(['productAtStop', 'timezoneOffset', 'id', 'extId', 'name', 'lon', 'lat', 'weight', 'products', 'meta', 'minimumChangeDuration'])

# %%
stop_locations[0]["StopLocation"]["name"] , stop_locations[0]["StopLocation"]["extId"]
# Out:
# ('GÖTEBORG', '740098001')

# %%
print(f" {'Stop':<50} extd")
for stop_location in stop_locations:
    stop = stop_location["StopLocation"]
    print(f'{stop["name"] :<50} {stop["extId"]}')
# Out:
#  Stop                                               extd
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
def access_id_from_location(location):
    url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"

    try:
        response = requests.get(url)
        result = response.json()

        print(f"{'Name':<50} extId")

        for stop in result.get("stopLocationOrCoordLocation"):
            stop_data = next(iter(stop.values()))

            # returns None if extId doesn't exist
            if stop_data.get("extId"):
                print(f"{stop_data['name']:<50} {stop_data['extId']}")

    except requests.exceptions.RequestException as err:
        print(f"Network or HTTP error: {err}")

access_id_from_location("malm")
# Out:
# Name                                               extId
# Malm (Gullspång kn)                                740062061
# Malmö Centralstation                               740000003
# Malmö Triangeln station                            740001587
# Malmö Hyllie station                               740001586
# Malmö Svågertorp station                           740001546
# Malmö Persborg station                             740001486
# Malmö Rosengård station                            740001621
# MALMÖ                                              740098548
# Malmö Östervärn station                            740001483
# Malmö Fosieby station                              740001553

# %%
access_id_from_location("onsala")
# Out:
# Name                                               extId
# Onsala kyrka (Kungsbacka kn)                       740000092
# Onsala vårdcentral (Kungsbacka kn)                 740061484

# %%
access_id_from_location("skövde")
# Out:
# Name                                               extId
# Skövde Centralstation                              740000008
# Skåningstorpsvägen (Skövde kn)                     740062677
# Skultorp Platåvägen (Skövde kn)                    740025882
# Skultorp väg 26 (Skövde kn)                        740018317
# Skultorp trafikplats (Skövde kn)                   740018262
# Skövde Sandtorget                                  740020987
# Skövde Stadshuset                                  740024075
# Siriusvägen (Skövde kn)                            740062753
# Skövde Gruvgatan                                   740020204
# Skövde Vasagatan                                   740020205

# %% [markdown]
# # Timetable

# %%
# korsvägen
stop_id=740015578
url = f"https://api.resrobot.se/v2.1/departureBoard?id={stop_id}&format=json&accessId={API_KEY}"

response = requests.get(url)
results = response.json()
results.keys()
# Out:
# dict_keys(['Departure', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId'])

# %%
import pandas as pd

df_timetable = pd.DataFrame(results["Departure"])
df_timetable.head()
# Out:
#                    JourneyDetailRef JourneyStatus  \
# 0     {'ref': '1|385|3|1|15012025'}             P
# 1  {'ref': '1|72659|11|1|15012025'}             P
# 2   {'ref': '1|55062|1|1|15012025'}             P
# 3   {'ref': '1|72695|6|1|15012025'}             P
# 4   {'ref': '1|98482|0|1|15012025'}             P
#
#                                        ProductAtStop  \
# 0  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 1  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 2  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 3  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 4  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 3  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 4  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Notes                    name  \
# 0  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...    Länstrafik - Buss X4
# 1  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...    Länstrafik - Buss 63
# 2  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Spårväg 8
# 3  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...    Länstrafik - Buss 63
# 4  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Spårväg 2
#
#   type                   stop  \
# 0   ST     Göteborg Korsvägen
# 1   ST     Göteborg Korsvägen
# 2   ST     Göteborg Korsvägen
# 3   ST     Göteborg Korsvägen
# 4   ST  Göteborg Scandinavium
#
#                                               stopid  stopExtId        lon  \
# 0  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 1  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 2  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 3  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 4  A=1@O=Göteborg Scandinavium@X=11985875@Y=57700...  740025681  11.985875
#
#          lat      time        date  reachable                    direction  \
# 0  57.696742  16:16:00  2025-01-15       True          Kungälv resecentrum
# 1  57.696742  16:16:00  2025-01-15       True        Göteborg Linnéplatsen
# 2  57.696742  16:17:00  2025-01-15       True  Frölunda torg (Göteborg kn)
# 3  57.696742  16:17:00  2025-01-15       True               Göteborg Heden
# 4  57.700445  16:17:00  2025-01-15       True           Mölndals Innerstad
#
#   directionFlag
# 0             2
# 1             1
# 2             2
# 3             2
# 4             1

# %%
df_timetable.columns
# Out:
# Index(['JourneyDetailRef', 'JourneyStatus', 'ProductAtStop', 'Product',
#        'Notes', 'name', 'type', 'stop', 'stopid', 'stopExtId', 'lon', 'lat',
#        'time', 'date', 'reachable', 'direction', 'directionFlag'],
#       dtype='object')

# %%
df_timetable_clean = df_timetable[["name" , "stop" , "direction" , "stopExtId" , "time"]]
df_timetable_clean
# Out:
#                        name                   stop  \
# 0      Länstrafik - Buss X4     Göteborg Korsvägen
# 1      Länstrafik - Buss 63     Göteborg Korsvägen
# 2    Länstrafik - Spårväg 8     Göteborg Korsvägen
# 3      Länstrafik - Buss 63     Göteborg Korsvägen
# 4    Länstrafik - Spårväg 2  Göteborg Scandinavium
# ..                      ...                    ...
# 240   Länstrafik - Buss RÖD     Göteborg Korsvägen
# 241  Länstrafik - Spårväg 6     Göteborg Korsvägen
# 242    Länstrafik - Buss 61     Göteborg Korsvägen
# 243  Länstrafik - Spårväg 2     Göteborg Korsvägen
# 244    Länstrafik - Buss 18     Göteborg Korsvägen
#
#                          direction  stopExtId      time
# 0              Kungälv resecentrum  740015578  16:16:00
# 1            Göteborg Linnéplatsen  740015578  16:16:00
# 2      Frölunda torg (Göteborg kn)  740015578  16:17:00
# 3                   Göteborg Heden  740015578  16:17:00
# 4               Mölndals Innerstad  740025681  16:17:00
# ..                             ...        ...       ...
# 240           Önneröd (Härryda kn)  740015578  17:15:00
# 241       Göteborg Varmfrontsgatan  740015578  17:15:00
# 242       Masthugget (Göteborg kn)  740015578  17:16:00
# 243  Göteborg Axel Dahlströms torg  740015578  17:16:00
# 244        Kallebäck (Göteborg kn)  740015578  17:16:00
#
# [245 rows x 5 columns]

# %%
df_timetable_clean["name"].value_counts()
# Out:
# name
# Länstrafik - Spårväg 2    31
# Länstrafik - Spårväg 6    28
# Länstrafik - Buss 18      25
# Länstrafik - Spårväg 8    25
# Länstrafik - Buss X4      24
# Länstrafik - Buss RÖD     19
# Länstrafik - Buss 63      16
# Länstrafik - Spårväg 5    15
# Länstrafik - Buss 61      15
# Länstrafik - Spårväg 4    14
# Länstrafik - Buss 758     12
# Länstrafik - Buss 100      8
# Länstrafik - Buss 300      7
# Länstrafik - Buss 101      3
# Flygtransfer - Buss .      2
# Expressbuss 611            1
# Name: count, dtype: int64
