# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_yh_region.csv")

df.head()
# Out:
#    Unnamed: 0  Blekinge  Dalarna  Gotland  Gävleborg  Halland  Jämtland  \
# 0        2007        14       21        0         15       14         9
# 1        2008        18       24        0         15       13         7
# 2        2009        13       21        0         16       13         5
# 3        2010         9       21        0         14       17         6
# 4        2011        12       22        1         10       18         6
#
#    Jönköping  Kalmar  Kronoberg  ...  Stockholm  Södermanland  Uppsala  \
# 0         31      18         23  ...        113            20       11
# 1         33      14         24  ...        118            17       12
# 2         26      16         27  ...        121            17       15
# 3         26      19         21  ...        139            16       14
# 4         30      16         16  ...        145            12       15
#
#    Värmland  Västerbotten  Västernorrland  Västmanland  Västra Götaland  \
# ...

# %%
df = df.set_index("Year")

#df.index.name = "Year"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = df.set_index("Year")
#       3 #df.index.name = "Year"
#
# AttributeError: 'str' object has no attribute 'set_index'
